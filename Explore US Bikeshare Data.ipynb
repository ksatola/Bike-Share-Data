# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Understanding data

# %%
#df = pd.read_csv("chicago.csv")
df = pd.read_csv("new_york_city.csv")

# %%
df.shape
# Out:
# (300000, 9)

# %%
df.head()
# Out:
#    Unnamed: 0           Start Time             End Time  Trip Duration  \
# 0     5688089  2017-06-11 14:55:05  2017-06-11 15:08:21            795
# 1     4096714  2017-05-11 15:30:11  2017-05-11 15:41:43            692
# 2     2173887  2017-03-29 13:26:26  2017-03-29 13:48:31           1325
# 3     3945638  2017-05-08 19:47:18  2017-05-08 19:59:01            703
# 4     6208972  2017-06-21 07:49:16  2017-06-21 07:54:46            329
#
#              Start Station             End Station   User Type  Gender  \
# 0  Suffolk St & Stanton St  W Broadway & Spring St  Subscriber    Male
# 1  Lexington Ave & E 63 St         1 Ave & E 78 St  Subscriber    Male
# 2        1 Pl & Clinton St    Henry St & Degraw St  Subscriber    Male
# 3    Barrow St & Hudson St         W 20 St & 8 Ave  Subscriber  Female
# 4          1 Ave & E 44 St         E 53 St & 3 Ave  Subscriber    Male
#
#    Birth Year
# 0      1998.0
# 1      1981.0
# 2      1987.0
# 3      1986.0
# 4      1992.0

# %%
df
# Out:
#         Unnamed: 0           Start Time             End Time  Trip Duration  \
# 0          5688089  2017-06-11 14:55:05  2017-06-11 15:08:21            795
# 1          4096714  2017-05-11 15:30:11  2017-05-11 15:41:43            692
# 2          2173887  2017-03-29 13:26:26  2017-03-29 13:48:31           1325
# 3          3945638  2017-05-08 19:47:18  2017-05-08 19:59:01            703
# 4          6208972  2017-06-21 07:49:16  2017-06-21 07:54:46            329
# 5          1285652  2017-02-22 18:55:24  2017-02-22 19:12:03            998
# 6          1675753  2017-03-06 16:22:53  2017-03-06 16:30:51            478
# 7          1692245  2017-03-07 07:42:24  2017-03-07 08:49:42           4038
# 8          2271331  2017-04-02 08:02:36  2017-04-02 09:28:08           5132
# 9          1558339  2017-03-01 23:01:31  2017-03-01 23:06:41            309
# 10         2287178  2017-04-02 14:37:20  2017-04-02 14:56:12           1131
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Start Time', 'End Time', 'Trip Duration',
#        'Start Station', 'End Station', 'User Type', 'Gender', 'Birth Year'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Unnamed: 0  Trip Duration     Birth Year
# count  3.000000e+05   3.000000e+05  271780.000000
# mean   3.407026e+06   8.996842e+02    1978.254309
# std    1.965617e+06   5.710016e+03      11.848045
# min    3.300000e+01   6.100000e+01    1885.000000
# 25%    1.707416e+06   3.680000e+02    1970.000000
# 50%    3.405756e+06   6.090000e+02    1981.000000
# 75%    5.108762e+06   1.054000e+03    1988.000000
# max    6.816152e+06   2.155775e+06    2001.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 9 columns):
# Unnamed: 0       300000 non-null int64
# Start Time       300000 non-null object
# End Time         300000 non-null object
# Trip Duration    300000 non-null int64
# Start Station    300000 non-null object
# End Station      300000 non-null object
# User Type        299308 non-null object
# Gender           270791 non-null object
# Birth Year       271780 non-null float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 20.6+ MB

# %%
#df.corr

# %%
#df['Start Time'].value_counts()
df['Trip Duration'].value_counts()
# Out:
# 331       412
# 368       402
# 401       399
# 375       392
# 410       392
# 318       389
# 397       389
# 385       388
# 317       388
# 371       384
# 383       383
# 342       381
# 380       381
# 338       380
# 337       378
# 319       378
# 421       377
# 332       377
# 292       376
# 294       376
# 433       376
# 334       376
# 333       375
# 357       375
# 298       374
# 388       373
# 376       373
# 392       372
# 419       372
# 372       371
#          ...
# 6211        1
# 11135       1
# 5560        1
# 5181        1
# 3515        1
# 4318        1
# 4728        1
# 3646        1
# 6072        1
# 50983       1
# 52674       1
# 4472        1
# 5337        1
# 4027        1
# 8260        1
# 18898       1
# 11230       1
# 4216        1
# 202777      1
# 8058        1
# 11388       1
# 4825        1
# 10942       1
# 5186        1
# 109644      1
# 3393        1
# 7491        1
# 4569        1
# 5698        1
# 7506        1
# ...

# %%
df['Trip Duration'].mean()
# Out:
# 899.68416

# %%
df['Trip Duration'].median()
# Out:
# 609.0

# %%
df['Trip Duration'].unique()
# Out:
# array([ 795,  692, 1325, ..., 3611, 5819, 3833])

# %%
df['Trip Duration'].mode()
# Out:
# 0    331
# dtype: int64

# %%
df['Birth Year'].value_counts()
# Out:
# 1989.0    11126
# 1985.0    11006
# 1986.0    10959
# 1988.0    10950
# 1987.0    10839
# 1990.0    10809
# 1984.0    10290
# 1991.0     9842
# 1983.0     9589
# 1982.0     8658
# 1992.0     8509
# 1981.0     8227
# 1980.0     7791
# 1979.0     6960
# 1993.0     6706
# 1978.0     6599
# 1976.0     6147
# 1977.0     6061
# 1970.0     5973
# 1974.0     5908
# 1971.0     5646
# 1975.0     5475
# 1973.0     5379
# 1972.0     5345
# 1969.0     5320
# 1968.0     4842
# 1967.0     4443
# 1965.0     4426
# 1966.0     4355
# 1964.0     4334
#           ...
# 1938.0       60
# 2001.0       38
# 1900.0       29
# 1934.0       27
# 1939.0       23
# 1936.0       16
# 1932.0       16
# 1937.0       14
# 1899.0       13
# 1901.0       13
# 1885.0       13
# 1926.0       10
# 1893.0        8
# 1910.0        7
# 1912.0        7
# 1923.0        6
# 1935.0        6
# 1917.0        5
# 1933.0        4
# 1931.0        3
# 1928.0        3
# 1927.0        3
# 1913.0        2
# 1895.0        2
# ...

# %%
CITY_DATA = { 'chicago': 'chicago.csv',
              'new york city': 'new_york_city.csv',
              'washington': 'washington.csv' }

# %%
CITY_DATA['chicago']
# Out:
# 'chicago.csv'

# %%
df['User Type'].value_counts()
# Out:
# Subscriber    269149
# Customer       30159
# Name: User Type, dtype: int64

# %%
popular_start_station = df['Start Station'].mode()[0]
popular_start_station
# Out:
# 'Pershing Square North'

# %%
df[df['Start Station'] == popular_start_station].count()[0]
# Out:
# 3069

# %%
df.count()
# Out:
# Unnamed: 0       300000
# Start Time       300000
# End Time         300000
# Trip Duration    300000
# Start Station    300000
# End Station      300000
# User Type        299308
# Gender           270791
# Birth Year       271780
# dtype: int64

# %%
df['Trip'] = 'FROM: ' + df['Start Station'] + ' TO: '+ df['End Station']

# %%
df['Trip'].mode()[0]
# Out:
# 'FROM: E 7 St & Avenue A TO: Cooper Square & E 7 St'

# %%
max_dur = df['Trip Duration'].sum()
max_dur
# Out:
# 269905248

# %%
pd.to_datetime(max_dur, unit='s')
# Out:
# Timestamp('1978-07-21 21:40:48')

# %%
import datetime

# %%
max_dur = max_dur.astype('float64')

# %%
str(datetime.timedelta(seconds=max_dur.astype('float64')))
# Out:
# '3123 days, 21:40:48'

# %%
type(max_dur)
# Out:
# numpy.float64

# %%
sec = 65000
day = sec // (24 * 3600)
time = sec % (24 * 3600)
hour = sec // 3600
sec %= 3600
minutes = sec // 60
sec %= 60
seconds = sec
print("d:h:m:s-> %d:%d:%d:%d" % (day, hour, minutes, seconds))
# Out:
# d:h:m:s-> 0:18:3:20

# %%
round(df['Trip Duration'].mean())
# Out:
# 900

# %%
df['Trip Duration'].mean()
# Out:
# 899.68416

# %%
df['Trip Duration'].min()
# Out:
# 61

# %%
df['User Type'].value_counts().to_dict()
# Out:
# {'Subscriber': 269149, 'Customer': 30159}

# %%
df.iloc[3]
# Out:
# Unnamed: 0                                               3945638
# Start Time                                   2017-05-08 19:47:18
# End Time                                     2017-05-08 19:59:01
# Trip Duration                                                703
# Start Station                              Barrow St & Hudson St
# End Station                                      W 20 St & 8 Ave
# User Type                                             Subscriber
# Gender                                                    Female
# Birth Year                                                  1986
# Trip             FROM: Barrow St & Hudson St TO: W 20 St & 8 Ave
# Name: 3, dtype: object

# %%
df.iloc[6:10]
# Out:
#    Unnamed: 0           Start Time             End Time  Trip Duration  \
# 6     1675753  2017-03-06 16:22:53  2017-03-06 16:30:51            478
# 7     1692245  2017-03-07 07:42:24  2017-03-07 08:49:42           4038
# 8     2271331  2017-04-02 08:02:36  2017-04-02 09:28:08           5132
# 9     1558339  2017-03-01 23:01:31  2017-03-01 23:06:41            309
#
#             Start Station                     End Station   User Type Gender  \
# 6      Front St & Gold St  Lafayette Ave & Fort Greene Pl  Subscriber   Male
# 7      E 89 St & York Ave           Broadway & Battery Pl  Subscriber   Male
# 8  Central Park S & 6 Ave          Central Park S & 6 Ave    Customer    NaN
# 9          E 3 St & 1 Ave                 E 25 St & 2 Ave  Subscriber   Male
#
#    Birth Year                                               Trip
# 6      1982.0  FROM: Front St & Gold St TO: Lafayette Ave & F...
# 7      1984.0  FROM: E 89 St & York Ave TO: Broadway & Batter...
# ...
